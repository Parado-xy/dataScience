# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Let's import the CSV file.
music = pd.read_csv(filepath_or_buffer = 'top2018.csv')
music.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
# Let's drop the id column.
music.drop('id', axis = 1, inplace = True)
music.head()
# Out:
#                            name       artists  danceability  energy  key  \
# 0                    God's Plan         Drake         0.754   0.449  7.0
# 1                          SAD!  XXXTENTACION         0.740   0.613  8.0
# 2    rockstar (feat. 21 Savage)   Post Malone         0.587   0.535  5.0
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559  8.0
# 4                In My Feelings         Drake         0.835   0.626  1.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.211   1.0       0.1090        0.0332          0.000083     0.552
# 1    -4.880   1.0       0.1450        0.2580          0.003720     0.123
# 2    -6.090   0.0       0.0898        0.1170          0.000066     0.131
# 3    -8.011   1.0       0.1170        0.5800          0.000000     0.112
# 4    -5.833   1.0       0.1250        0.0589          0.000060     0.396
#
#    valence    tempo  duration_ms  time_signature
# ...

# %%
music['rank'] = range(1, music.shape[0] + 1)
music.head()
# Out:
#                            name       artists  danceability  energy  key  \
# 0                    God's Plan         Drake         0.754   0.449  7.0
# 1                          SAD!  XXXTENTACION         0.740   0.613  8.0
# 2    rockstar (feat. 21 Savage)   Post Malone         0.587   0.535  5.0
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559  8.0
# 4                In My Feelings         Drake         0.835   0.626  1.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.211   1.0       0.1090        0.0332          0.000083     0.552
# 1    -4.880   1.0       0.1450        0.2580          0.003720     0.123
# 2    -6.090   0.0       0.0898        0.1170          0.000066     0.131
# 3    -8.011   1.0       0.1170        0.5800          0.000000     0.112
# 4    -5.833   1.0       0.1250        0.0589          0.000060     0.396
#
#    valence    tempo  duration_ms  time_signature  rank
# ...

# %%
# Let's check out descriptive stats. 
music.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count     100.00000  100.000000  100.000000  100.000000  100.000000
# mean        0.71646    0.659060    5.330000   -5.677640    0.590000
# std         0.13107    0.145067    3.676447    1.777577    0.494311
# min         0.25800    0.296000    0.000000  -10.109000    0.000000
# 25%         0.63550    0.562000    1.750000   -6.650500    0.000000
# 50%         0.73300    0.678000    5.000000   -5.566500    1.000000
# 75%         0.79825    0.772250    8.250000   -4.363750    1.000000
# max         0.96400    0.909000   11.000000   -2.384000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.115569      0.195701          0.001584    0.158302    0.484443
# std       0.104527      0.220946          0.013449    0.111662    0.206145
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              100 non-null    object
#  1   artists           100 non-null    object
#  2   danceability      100 non-null    float64
#  3   energy            100 non-null    float64
#  4   key               100 non-null    float64
#  5   loudness          100 non-null    float64
#  6   mode              100 non-null    float64
#  7   speechiness       100 non-null    float64
#  8   acousticness      100 non-null    float64
#  9   instrumentalness  100 non-null    float64
#  10  liveness          100 non-null    float64
#  11  valence           100 non-null    float64
#  12  tempo             100 non-null    float64
#  13  duration_ms       100 non-null    float64
#  14  time_signature    100 non-null    float64
#  15  rank              100 non-null    int64
# ...

# %%
music.query('artists == "XXXTENTACION"')
# Out:
#                                   name       artists  danceability  energy  \
# 1                                 SAD!  XXXTENTACION         0.740   0.613
# 18                           Moonlight  XXXTENTACION         0.921   0.537
# 28                      Jocelyn Flores  XXXTENTACION         0.872   0.391
# 38                             changes  XXXTENTACION         0.669   0.308
# 62      Fuck Love (feat. Trippie Redd)  XXXTENTACION         0.797   0.533
# 94  Everybody Dies In Their Nightmares  XXXTENTACION         0.734   0.570
#
#      key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 1    8.0    -4.880   1.0       0.1450        0.2580          0.003720
# 18   9.0    -5.723   0.0       0.0804        0.5560          0.004040
# 28   0.0    -9.144   0.0       0.2420        0.4690          0.000004
# 38  11.0   -10.068   1.0       0.0290        0.8830          0.000000
# 62   0.0    -9.740   0.0       0.0412        0.0172          0.000152
# ...
